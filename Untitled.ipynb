# %%
import pandas as pd
from pathlib import Path
import random

# %%
from IPython.display import Image, display

import random
# Additional library
one = "1.0.png"
two = "1.14.png"
three = "1.3.png"

# %%
image_list = [one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,one,two,two,two,two,two,two,two,two,three,three,three,three,three,three,three]

# %%
random.shuffle(image_list)

# %%
print(image_list)
# Out:
# ['1.3.png', '1.0.png', '1.14.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.3.png', '1.0.png', '1.3.png', '1.14.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.3.png', '1.14.png', '1.0.png', '1.14.png', '1.14.png', '1.0.png', '1.0.png', '1.3.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.14.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.3.png', '1.14.png', '1.0.png', '1.0.png', '1.3.png', '1.14.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png', '1.0.png']

# %%
image_list[0]
# Out:
# '1.3.png'

# %%
for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %%
put all images into a list
shuffle it once
set placeholder value
set binary where they're at 0 then when theyre picked it flips to 1
# Out:
#   Input In [142]
#     put all images into a list
#         ^
# SyntaxError: invalid syntax
